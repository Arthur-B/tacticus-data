# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load and check the data

# %%
PATH_MAT = './data/materials_cleaned.csv'
df = pd.read_csv(PATH_MAT, index_col=0)
df
# Out:
#                          Item     Rarity    Stat  Craftable  \
# 0        Adamantium Filaments     Common  Health      False
# 1              Adamantium Ore     Common  Armour      False
# 2                  Armor Trim     Common  Armour      False
# 3                      Auspex     Common  Damage      False
# 4             Ballistics Data     Common  Damage      False
# ..                        ...        ...     ...        ...
# 327        Tannhauser's Bones  Legendary  Health       True
# 328  Tome of Arcane Knowledge  Legendary  Health       True
# 329  Transdimensional Sanctum  Legendary  Armour       True
# 330           Virulent Rounds  Legendary  Damage       True
# 332         Witchseeker Bolts  Legendary  Damage       True
#
#                     Item 1  Quantity 1                        Item 2  \
# 0                      NaN         NaN                           NaN
# 1                      NaN         NaN                           NaN
# 2                      NaN         NaN                           NaN
# 3                      NaN         NaN                           NaN
# 4                      NaN         NaN                           NaN
# ..                     ...         ...                           ...
# 327  Bones of the Paragons         9.0            Grand Skull Trophy
# 328   Ominous Xenos Glyphs         1.0  Mutation: Regenerative Blood
# 329  Engrammatic Entangler         9.0     Viridian Energy Tesseract
# 330     Blessing of Nurgle         9.0            Supernatural Sight
# 332  Bones of the Paragons         9.0                    Prey-Sight
#
#      Quantity 2                           Item 3  Quantity 3 Unnamed: 10  \
# 0           NaN                              NaN         NaN         NaN
# 1           NaN                              NaN         NaN         NaN
# 2           NaN                              NaN         NaN         NaN
# 3           NaN                              NaN         NaN         NaN
# 4           NaN                              NaN         NaN         NaN
# ..          ...                              ...         ...         ...
# 327         1.0               Terminator Honours         6.0         NaN
# 328         1.0  Greater Reliquary of Protection         1.0         NaN
# 329         9.0            Hypermaterial Shifter         5.0         NaN
# 330         1.0               Special Issue Ammo         6.0         NaN
# 332         1.0               Special Issue Ammo         6.0         NaN
#
#      Average energy cost
# 0               7.142857
# 1               7.142857
# 2               7.142857
# 3               7.202881
# 4               7.142857
# ..                   ...
# 327           285.640472
# 328           172.912408
# 329           273.648649
# 330           309.873950
# 332           310.234094
#
# [328 rows x 12 columns]

# %%
df.loc[df['Average energy cost'].isna()]
# Out:
#                                    Item     Rarity    Stat  Craftable  \
# 107                     Chapter Pendant       Rare  Damage      False
# 124                    Key of Ignorance       Rare  Health      False
# 173                  Bolts of Judgement       Epic  Damage       True
# 199                    Key of Knowledge       Epic  Health       True
# 211                          Relic Hilt       Epic  Damage      False
# 231                      Arbiter's Gaze  Legendary  Damage       True
# 244          Bolts of Furious Vengeance  Legendary  Damage       True
# 276                    Key of Achrabael  Legendary  Health       True
# 293  Perfidious Relic of the Unforgiven  Legendary  Health       True
# 297                      Powered Blades  Legendary  Damage       True
# 315                    Shroud of Heroes  Legendary  Armour       True
# 322             Stone Guardian Fragment  Legendary  Health      False
#
#                       Item 1  Quantity 1                           Item 2  \
# 107                      NaN         NaN                              NaN
# 124                      NaN         NaN                              NaN
# 173          Chapter Pendant         9.0                              NaN
# 199         Key of Ignorance         9.0                              NaN
# 211                      NaN         NaN                              NaN
# 231  Stone Guardian Fragment         9.0                       Bionic Eye
# 244       Bolts of Judgement         2.0           Sanctified Weapon Oils
# 276         Key of Knowledge         2.0  Greater Reliquary of Protection
# 293  Stone Guardian Fragment         9.0            Impressive Armor Trim
# 297        Adamantium Blades         1.0                       Relic Hilt
# 315  Stone Guardian Fragment         9.0                  Decorated Cloak
# 322                      NaN         NaN                              NaN
#
#      Quantity 2                    Item 3  Quantity 3 Unnamed: 10  \
# 107         NaN                       NaN         NaN         NaN
# 124         NaN                       NaN         NaN         NaN
# 173         NaN                       NaN         NaN         NaN
# 199         NaN                       NaN         NaN         NaN
# 211         NaN                       NaN         NaN         NaN
# 231         8.0    Bionic Neural Pathways         6.0         NaN
# 244         1.0                       NaN         NaN         NaN
# 276         1.0                       NaN         NaN         NaN
# 293         2.0        Terminator Honours         5.0         NaN
# 297         4.0  Anointed Micro-Generator         1.0         NaN
# 315         1.0        Terminator Honours         5.0         NaN
# 322         NaN                       NaN         NaN         NaN
#
#      Average energy cost
# 107                  NaN
# 124                  NaN
# 173                  NaN
# 199                  NaN
# 211                  NaN
# 231                  NaN
# 244                  NaN
# 276                  NaN
# 293                  NaN
# 297                  NaN
# 315                  NaN
# 322                  NaN
