# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# # Load and check the data

# %%
PATH_MAT = './data/materials_cleaned.csv'
df = pd.read_csv(PATH_MAT, index_col=0)
df
# Out:
#                          Item     Rarity    Stat  Craftable  \
# 0        Adamantium Filaments     Common  Health      False
# 1              Adamantium Ore     Common  Armour      False
# 2                  Armor Trim     Common  Armour      False
# 3                      Auspex     Common  Damage      False
# 4             Ballistics Data     Common  Damage      False
# ..                        ...        ...     ...        ...
# 327        Tannhauser's Bones  Legendary  Health       True
# 328  Tome of Arcane Knowledge  Legendary  Health       True
# 329  Transdimensional Sanctum  Legendary  Armour       True
# 330           Virulent Rounds  Legendary  Damage       True
# 332         Witchseeker Bolts  Legendary  Damage       True
#
#                     Item 1  Quantity 1                        Item 2  \
# 0                      NaN         NaN                           NaN
# 1                      NaN         NaN                           NaN
# ...

# %%
df.loc[df['Average energy cost'].isna()]
# Out:
# Empty DataFrame
# Columns: [Item, Rarity, Stat, Craftable, Item 1, Quantity 1, Item 2, Quantity 2, Item 3, Quantity 3, Unnamed: 10, Average energy cost]
# Index: []

# %%
fig, axs = plt.subplots(2, 2)

for i, (ax, rarity) in enumerate(zip(axs.flatten(), ["Uncommon", "Rare", "Epic", "Legendary"])):
    sns.histplot(data=df[df[["Craftable", "Rarity"]].eq([True, rarity]).all(1)], 
                x="Average energy cost",
                ax=ax)
    ax.set_title(rarity)
plt.tight_layout()
plt.show()

# %%
# fig, axs = plt.subplots(4, 1, sharex=True, sharey=True, dpi=300, figsize=(4,10))
fig, axs = plt.subplots(3, 1, sharex=True, sharey=True, dpi=150, figsize=(4,5))

for i, (ax, rarity) in enumerate(zip(axs.flatten(), ["Rare", "Epic", "Legendary"])):
    data = df[df[["Craftable", "Rarity"]].eq([True, rarity]).all(1)]
    sns.histplot(data=data, 
                x="Average energy cost",
                ax=ax)
    ax.set_title(rarity)
    ax.axvline(data["Average energy cost"].mean())
plt.tight_layout()
plt.show()

# %%
df[df[["Craftable", "Rarity"]].eq([True, "Rare"]).all(1)].sort_values("Average energy cost")
# Out:
#                                    Item Rarity    Stat  Craftable  \
# 122               Impressive Armor Trim   Rare  Armour       True
# 94                          Battle Plan   Rare  Health       True
# 118                  Grand Skull Trophy   Rare  Health       True
# 116                          Fine Cloak   Rare  Armour       True
# 135                  Plasma Cell Bundle   Rare  Damage       True
# 101                 Blessed Purity Seal   Rare  Armour       True
# 133               Mutation: Warped Skin   Rare  Armour       True
# 147                  Scale-Plate Strand   Rare  Armour       True
# 128                  Mesh Weave Garment   Rare  Armour       True
# 105                        Ceramite Bar   Rare  Armour       True
# 150          Sophisticated Material Bar   Rare  Armour       True
# 86                       Adamantium Bar   Rare  Armour       True
# 137            Powerful Micro-Generator   Rare  Damage       True
# ...

# %%
df[df[["Craftable", "Rarity"]].eq([True, "Epic"]).all(1)].sort_values("Average energy cost")
# Out:
#                                 Item Rarity    Stat  Craftable  \
# 226        Warp Touched Eye of Horus   Epic  Health       True
# 195                Hymn of Sacrifice   Epic  Damage       True
# 197                   Ice Troll Hide   Epic  Armour       True
# 198       Icon of Daemonic Vengeance   Epic  Damage       True
# 200              Lights of Purgation   Epic  Health       True
# 201                  Macharian Cross   Epic  Health       True
# 184                       Epaulettes   Epic  Health       True
# 183                   Ded 'Ard Plate   Epic  Armour       True
# 206                         Nob Teef   Epic  Health       True
# 181                     Death Shroud   Epic  Armour       True
# 180                       Death Bell   Epic  Health       True
# 224       Veteran's Entrenching Tool   Epic  Damage       True
# 179              Daemonic Armor Trim   Epic  Armour       True
# 177          Chain of Righteous Zeal   Epic  Damage       True
# ...
